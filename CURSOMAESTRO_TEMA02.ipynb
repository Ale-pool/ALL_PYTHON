# %% [markdown]
# <a href="https://colab.research.google.com/github/Ale-pool/ALL_PYTHON/blob/main/CURSOMAESTRO_TEMA02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *****TEMA DE OPERADORES Y EXPRESIONES EN PY*** **
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
# tipo logico
# la representacion matematica de true = 1 y de false = 0

f = 1+1 == 3
v = 3+4 == 7

print(f)
print(v)
# Out:
# False
# True

# %%
# operadores relacionales

print(3 == 2)
print(5 != 10)
print(4<5)
print(8>12)
print(12 <= 20)
print(13 <= 10)
print(22 <= 22)

a = 7
b = 19
c = 20
d = "1"
e = "2"

print(f"que da este operación {a < b}")
print(f"que da este operación {b < b}")
print(f"que da este operación {a == d}")
print(f"que da este operación {a != b}")
print(f"que da este operación {a > b*2}")
# Out:
# False
# True
# True
# False
# True
# False
# True
# que da este operación True
# que da este operación False
# que da este operación False
# que da este operación True
# que da este operación False

# %%
# Y otros tipos, como cadenas, listas, el resultado de algunas funciones o los propios tipos lógicos

"hola" == "Hola"
"HOLA" == "HOLA"
"buenas" != "buenass"
# Out:
# True

# %%
# OPERADORES LOGICOS
# NOT , OR , AND

# NOT - NEGACION LOGICA
not False

not True == False

# And - Conjunción lógica (agrupa uniendo)

True and True == True
True and False == False
False and True == False
False and False == False

# OR - Disyunción lógica (agrupa separando)

True or True == True
True or False == True
False or True == True
False or False == False
# Out:
# True

# %%
a = 45
a > 10 and a < 60

c = "Hola mundo"
len(c) >= 20 or c[0] == "H"
# Out:
# True
