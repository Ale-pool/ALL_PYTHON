# %% [markdown]
# <a href="https://colab.research.google.com/github/Ale-pool/ALL_PYTHON/blob/main/CURSOMAESTROPART_3_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LECTURA POR TECLADO:

name = input("whats your name?: ")
lastname = input("whats your lastname?: ")
print(f"Heyy hola como estas {name} {lastname}")
age = int(input("how old are you?: "))
print(f"Perfecto {name} tu {age}, eres muy joven")
print("Bueno")
place = input("where are you from?: ")
place = place.lower()
print(f'{place} es u lugar fabuloso')

if age >= 18:
    if place == "colombia":
      print(f"Excelente {name} puedes ya ir a tomar en colombia")
    else:
      print(f"eres mayor de edad {name} pero no eres de colombia")
elif age < 18:
    print(f"Lastima tu eres de {place}, pero no puedes salir a tomar")
# Out:
# whats your name?: Alex
# whats your lastname?: Villada
# Heyy hola como estas Alex Villada
# how old are you?: 23
# Perfecto Alex tu 23, eres muy joven
# Bueno
# where are you from?: COLOMbia
# colombia es u lugar fabuloso
# Excelente Alex puedes ya ir a tomar en colombia

# %%
#Cast con int(), de cadena a entero
valor = int(input("Ingrese un valor: "))
print(f"El valor ingresado es: {valor}")
# Out:
# Ingrese un valor: 12
# El valor ingresado es: 12

# %%
# La función float() de flotante, devuelve un número flotante a partir de una cadena
valor = float(valor)
10 + valor
# Out:
# 22.0

# %%
"""
Inputs
Realiza un programa con los siguientes requisitos:
Debes leer por teclado dos cadenas de caracteres, una llamada nombre y otra llamada apellido.
Debes leer por teclado un número entero llamado edad (recuerda que la variable debe ser de tipo entero).
Debes leer por teclado un número flotante llamado numero_magico.
Finalmente debes crear una variable cadena_final con el siguiente formato:
NOMBRE APELLIDO: Tu número de la suerte es el EDAD*NUMERO_MAGICO
Por ejemplo, si se introducen los valores "Juan", "Pérez", 20 y 4.5 , cadena_final contendrá lo siguiente:
Juan Pérez: Tu número de la suerte es el 90.0
"""

nombre = input("Ingrese su nombre:")
apellido = input("Ingrese su apellido: ")
edad = int(input("Ingrese su edad: "))
numero_magico = float(input("Ingrese un numero: "))
cadena_final = f"{nombre} {apellido} : Tu numero de la suerte es el {edad * numero_magico}"
print(cadena_final)
# Out:
# Ingrese su nombre:Alexander
# Ingrese su apellido: Villada
# Ingrese su edad: 24
# Ingrese un numero: 7
# Alexander Villada : Tu numero de la suerte es el 168.0

# %%
n = 0
val = 10000
while n < val:  # while = mientras
    if (n % 2) == 0: # if = si (de condicion)
        print(n,'es un número par')
    else:  # else = sino (def condicion)
        print(n,'es un número impar')
    n = n + 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# EJERCICIO 1
# "HOLA MUNDO" STR
# [1,10,100] --> LISTA
# -25 -> entero
# 1.167 -> float
# ["HOLA","MUNDO"] --> LISTA
# Out:
# ['HOLA', 'MUNDO']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = -5
c = "Hola "
d = [1,2,3]

# ===============#

print(a * 5) # 50
print(a - b)  # 5
print(c + "Mundo") # Hola  mundo
print( c * 2) # Hola Hola
print(c[-1]) # vacio
print(c[1:]) # ola
print(d + d) # [1, 2, 3, 1, 2, 3]
# Out:
# 50
# 15
# Hola Mundo
# Hola Hola
#
# ola
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numero_1 = 9
numero_2 = 3
numer0_3 = 6

media = (numero_1 + numero_2 + numer0_3) / 3
print(f"la nota media es {media}")
val = 9 + 3 + 2.0
val
# Out:
# la nota media es 6.0
# 14.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nota_1 = 10
nota_2 = 7
nota_3 = 4


mediaporcentaje = ((nota_1 * 0.15) + (nota_2 * 0.35) + (nota_3 * 0.50))
print(round(mediaporcentaje, 2))
# Out:
# 5.95

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
matriz = [
    [1,1,1,3],
    [2,2,2,7],
    [3,3,3,9],
    [4,4,4,13]
]


matriz[0][3] = sum(matriz[0][:3])
matriz[1][3] = sum(matriz[1][:3])
matriz[2][3] = sum(matriz[2][:3])
matriz[3][3]  = sum(matriz[3][:3])

matriz_modi = matriz
print(matriz_modi)
matriz
# Out:
# [[1, 1, 1, 3], [2, 2, 2, 6], [3, 3, 3, 9], [4, 4, 4, 12]]
# [[1, 1, 1, 3], [2, 2, 2, 6], [3, 3, 3, 9], [4, 4, 4, 12]]

# %%
for fila in matriz:
  suma = sum(fila[:3])
  fila = suma

print(matriz)
# Out:
# [[1, 1, 1, 3], [2, 2, 2, 6], [3, 3, 3, 9], [4, 4, 4, 12]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cadena = "zerép nauj,01"
modi = cadena[::-1]
print(modi)
nombre = modi[3:8]
print(nombre)
apellido = modi[8:13]
print(apellido)
nota  = modi[0:2]
print(nota)
print(f"el estudiante {nombre} {apellido} ha sacado una nota de {nota}")
# Out:
# 10,juan pérez
# juan
# pérez
# 10
# el estudiante juan  pérez ha sacado una nota de 10
